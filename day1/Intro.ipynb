# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/fiat500.csv')
data
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 0        1  lounge            51          882   25000                1
# 1        2     pop            51         1186   32500                1
# 2        3   sport            74         4658  142228                1
# 3        4  lounge            51         2739  160000                1
# 4        5     pop            73         3074  106880                1
# ...    ...     ...           ...          ...     ...              ...
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 1     45.666359  12.241890   8800
# ...

# %% [markdown]
# To find the number of rows and columns

# %%
data.shape
# Out:
# (1538, 9)

# %% [markdown]
# INFO - gives the information about the columns/attributes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1538 entries, 0 to 1537
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               1538 non-null   int64
#  1   model            1538 non-null   object
#  2   engine_power     1538 non-null   int64
#  3   age_in_days      1538 non-null   int64
#  4   km               1538 non-null   int64
#  5   previous_owners  1538 non-null   int64
#  6   lat              1538 non-null   float64
#  7   lon              1538 non-null   float64
#  8   price            1538 non-null   int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 108.3+ KB

# %% [markdown]
# Describe : Used to decribe the set of numerical variables

# %%
data.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1538.000000   1538.000000  1538.000000    1538.000000      1538.000000
# mean    769.500000     51.904421  1650.980494   53396.011704         1.123537
# std     444.126671      3.988023  1289.522278   40046.830723         0.416423
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     385.250000     51.000000   670.000000   20006.250000         1.000000
# 50%     769.500000     51.000000  1035.000000   39031.000000         1.000000
# 75%    1153.750000     51.000000  2616.000000   79667.750000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat          lon         price
# count  1538.000000  1538.000000   1538.000000
# mean     43.541361    11.563428   8576.003901
# std       2.133518     2.328190   1939.958641
# min      36.855839     7.245400   2500.000000
# ...

# %%
data.isnull()
# Out:
#          ID  model  engine_power  age_in_days     km  previous_owners    lat  \
# 0     False  False         False        False  False            False  False
# 1     False  False         False        False  False            False  False
# 2     False  False         False        False  False            False  False
# 3     False  False         False        False  False            False  False
# 4     False  False         False        False  False            False  False
# ...     ...    ...           ...          ...    ...              ...    ...
# 1533  False  False         False        False  False            False  False
# 1534  False  False         False        False  False            False  False
# 1535  False  False         False        False  False            False  False
# 1536  False  False         False        False  False            False  False
# 1537  False  False         False        False  False            False  False
#
#         lon  price
# 0     False  False
# ...

# %%
data.isna()
# Out:
#          ID  model  engine_power  age_in_days     km  previous_owners    lat  \
# 0     False  False         False        False  False            False  False
# 1     False  False         False        False  False            False  False
# 2     False  False         False        False  False            False  False
# 3     False  False         False        False  False            False  False
# 4     False  False         False        False  False            False  False
# ...     ...    ...           ...          ...    ...              ...    ...
# 1533  False  False         False        False  False            False  False
# 1534  False  False         False        False  False            False  False
# 1535  False  False         False        False  False            False  False
# 1536  False  False         False        False  False            False  False
# 1537  False  False         False        False  False            False  False
#
#         lon  price
# 0     False  False
# ...

# %%
data.head(20)
# Out:
#     ID   model  engine_power  age_in_days      km  previous_owners        lat  \
# 0    1  lounge            51          882   25000                1  44.907242
# 1    2     pop            51         1186   32500                1  45.666359
# 2    3   sport            74         4658  142228                1  45.503300
# 3    4  lounge            51         2739  160000                1  40.633171
# 4    5     pop            73         3074  106880                1  41.903221
# 5    6     pop            74         3623   70225                1  45.000702
# 6    7  lounge            51          731   11600                1  44.907242
# 7    8  lounge            51         1521   49076                1  41.903221
# 8    9   sport            73         4049   76000                1  45.548000
# 9   10   sport            51         3653   89000                1  45.438301
# 10  11     pop            51          790   43286                1  40.871429
# ...

# %%
data.tail(20)
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 1518  1519  lounge            51          397   16053                1
# 1519  1520  lounge            51          670   30000                1
# 1520  1521  lounge            51         1035   15000                1
# 1521  1522  lounge            51         3774   85000                1
# 1522  1523  lounge            51          366   14618                1
# 1523  1524     pop            51         2251   79800                1
# 1524  1525     pop            51         2192   53300                1
# 1525  1526  lounge            51          790   41870                1
# 1526  1527  lounge            51         1705   23600                1
# 1527  1528     pop            51          517    3000                1
# 1528  1529  lounge            51         2861  126000                1
# 1529  1530  lounge            51          731   22551                1
# ...

# %%
list(data)
# Out:
# ['ID',
#  'model',
#  'engine_power',
#  'age_in_days',
#  'km',
#  'previous_owners',
#  'lat',
#  'lon',
#  'price']

# %%
data['model'].head(10)
# Out:
# 0    lounge
# 1       pop
# 2     sport
# 3    lounge
# 4       pop
# 5       pop
# 6    lounge
# 7    lounge
# 8     sport
# 9     sport
# Name: model, dtype: object

# %%
data['model'].unique()
# Out:
# array(['lounge', 'pop', 'sport'], dtype=object)

# %%
data['previous_owners'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
data['model'].value_counts()
# Out:
# model
# lounge    1094
# pop        358
# sport       86
# Name: count, dtype: int64

# %%
data['model'].count()
# Out:
# 1538

# %%
data.groupby('previous_owners').sum()
# Out:
#                       ID                                              model  \
# previous_owners
# 1                1073172  loungepopsportloungepoppoploungeloungesportspo...
# 2                  82899  loungeloungesportloungepopsportloungepoppoplou...
# 3                  16736  sportloungeloungeloungesportpoploungeloungelou...
# 4                  10684  poploungeloungesportloungeloungeloungeloungelo...
#
#                  engine_power  age_in_days        km           lat  \
# previous_owners
# 1                       72082      2235925  72097167  60478.190224
# 2                        6104       247054   8023183   5097.668453
# 3                        1184        39514   1386014    994.757774
# 4                         459        16715    616702    395.997269
#
#                           lon     price
# previous_owners
# 1                16086.248019  11992447
# 2                 1334.995598    932229
# 3                  267.860445    193148
# ...

# %%
new_data=pd.get_dummies(data,dtype='int')
new_data
# Out:
#         ID  engine_power  age_in_days      km  previous_owners        lat  \
# 0        1            51          882   25000                1  44.907242
# 1        2            51         1186   32500                1  45.666359
# 2        3            74         4658  142228                1  45.503300
# 3        4            51         2739  160000                1  40.633171
# 4        5            73         3074  106880                1  41.903221
# ...    ...           ...          ...     ...              ...        ...
# 1533  1534            51         3712  115280                1  45.069679
# 1534  1535            74         3835  112000                1  45.845692
# 1535  1536            51         2223   60457                1  45.481541
# 1536  1537            51         2557   80750                1  45.000702
# 1537  1538            51         1766   54276                1  40.323410
#
#             lon  price  model_lounge  model_pop  model_sport
# ...

# %%
new_data.cov()
# Out:
#                             ID  engine_power   age_in_days            km  \
# ID               197248.500000    -60.325634 -3.479372e+04 -1.162613e+05
# engine_power        -60.325634     15.904327  1.641481e+03  4.559580e+04
# age_in_days      -34793.715680   1641.480893  1.662868e+06  4.306313e+07
# km              -116261.337671  45595.798126  4.306313e+07  1.603749e+09
# previous_owners       1.443071     -0.008354  4.069011e+01  1.626594e+03
# lat                 -55.153825      0.048676  1.732781e+02  3.034803e+03
# lon                  60.945909     -0.046725 -1.280972e+02  4.511967e+02
# price             24569.351334  -2144.857142 -2.234766e+06 -6.676402e+07
# model_lounge          3.864021     -0.241013 -1.519002e+02 -4.642608e+03
# model_pop            -1.340924      0.041781  5.905204e+01  1.845689e+03
# model_sport          -2.523097      0.199232  9.284820e+01  2.796919e+03
#
#                  previous_owners          lat         lon         price  \
# ...

# %%
corr=new_data.corr()

# %%
import seaborn as sns
sns.heatmap(corr,vmax=1,vmin=-1,annot=True,linewidth=.5,cmap='bwr')
# Out:
# <Axes: >

# %%
data1=data.drop(['lat','lon'],axis=1)
data1
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  price
# 0        1  lounge            51          882   25000                1   8900
# 1        2     pop            51         1186   32500                1   8800
# 2        3   sport            74         4658  142228                1   4200
# 3        4  lounge            51         2739  160000                1   6000
# 4        5     pop            73         3074  106880                1   5700
# ...    ...     ...           ...          ...     ...              ...    ...
# 1533  1534   sport            51         3712  115280                1   5200
# 1534  1535  lounge            74         3835  112000                1   4600
# 1535  1536     pop            51         2223   60457                1   7500
# 1536  1537  lounge            51         2557   80750                1   5990
# 1537  1538     pop            51         1766   54276                1   7900
#
# [1538 rows x 7 columns]

# %%
data2=data1.drop('ID',axis=1)
data2
# Out:
#        model  engine_power  age_in_days      km  previous_owners  price
# 0     lounge            51          882   25000                1   8900
# 1        pop            51         1186   32500                1   8800
# 2      sport            74         4658  142228                1   4200
# 3     lounge            51         2739  160000                1   6000
# 4        pop            73         3074  106880                1   5700
# ...      ...           ...          ...     ...              ...    ...
# 1533   sport            51         3712  115280                1   5200
# 1534  lounge            74         3835  112000                1   4600
# 1535     pop            51         2223   60457                1   7500
# 1536  lounge            51         2557   80750                1   5990
# 1537     pop            51         1766   54276                1   7900
#
# [1538 rows x 6 columns]

# %%
data3=data1.copy()
data3.columns
# Out:
# Index(['ID', 'model', 'engine_power', 'age_in_days', 'km', 'previous_owners',
#        'price'],
#       dtype='object')

# %%
X = data2.drop('price',axis=1)
X
# Out:
#        model  engine_power  age_in_days      km  previous_owners
# 0     lounge            51          882   25000                1
# 1        pop            51         1186   32500                1
# 2      sport            74         4658  142228                1
# 3     lounge            51         2739  160000                1
# 4        pop            73         3074  106880                1
# ...      ...           ...          ...     ...              ...
# 1533   sport            51         3712  115280                1
# 1534  lounge            74         3835  112000                1
# 1535     pop            51         2223   60457                1
# 1536  lounge            51         2557   80750                1
# 1537     pop            51         1766   54276                1
#
# [1538 rows x 5 columns]

# %%
y=data2['price']
y
# Out:
# 0       8900
# 1       8800
# 2       4200
# 3       6000
# 4       5700
#         ...
# 1533    5200
# 1534    4600
# 1535    7500
# 1536    5990
# 1537    7900
# Name: price, Length: 1538, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=0)

# %%
X_train
# Out:
#        model  engine_power  age_in_days      km  previous_owners
# 1479  lounge            51         1674   89000                1
# 431   lounge            51         2527   95000                1
# 194   lounge            51         3227  142000                1
# 240   lounge            51          397   13105                1
# 474      pop            51         1005   60879                1
# ...      ...           ...          ...     ...              ...
# 763   lounge            62         3227   79000                1
# 835      pop            51          366   16500                1
# 1216  lounge            51         3653  122649                1
# 559      pop            51          913   20000                1
# 684      pop            51          943   35481                1
#
# [1030 rows x 5 columns]

# %%
X_test
# Out:
#        model  engine_power  age_in_days      km  previous_owners
# 1440  lounge            51         4474  143900                1
# 54    lounge            51          701   11200                1
# 298   lounge            51          397   19286                1
# 1335  lounge            51          366   12950                1
# 861   lounge            51          821   26333                1
# ...      ...           ...          ...     ...              ...
# 1174     pop            51          366   14730                1
# 1223  lounge            51          640   33007                1
# 536   lounge            51          943   25006                1
# 1476  lounge            51          731   16500                1
# 1061  lounge            51         1278   24162                1
#
# [508 rows x 5 columns]

# %%
y_train
# Out:
# 1479     7600
# 431      7500
# 194      4900
# 240     10500
# 474      8350
#         ...
# 763      8500
# 835     10500
# 1216     5300
# 559      8499
# 684      8650
# Name: price, Length: 1030, dtype: int64

# %%
y_test
# Out:
# 1440     5400
# 54      10600
# 298      9980
# 1335    10400
# 861      9800
#         ...
# 1174     9500
# 1223     9700
# 536     10900
# 1476    10500
# 1061     8990
# Name: price, Length: 508, dtype: int64
